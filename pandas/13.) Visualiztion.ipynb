# %%
google.plot(y="High")

# %%
google.plot(y="Close")

# %%
google["Open"].plot()

# %%
google[["High","Low"]].plot()

# %% [markdown]
# # Mdefying Aesthetics

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
google.plot()

# %%
google.plot(y="Open")

# %%
plt.style.use("fivethirtyeight")
google.plot(y="Close")

# %%
plt.style.use("dark_background")
google.plot(y="Close")

# %%
plt.style.use("ggplot")
google.plot(y="Close")

# %% [markdown]
# # Bar Graphs

# %%
def rank_performance(stock_price):
    if stock_price <=500:
        return "Poor"
    elif stock_price >500 and stock_price <=800:
        return "Satifactory"
    else:
        return "Stellar"

# %%
google["Close"].apply(rank_performance).value_counts()
# Out:
# Satifactory    697
# Stellar        306
# Poor             4
# Name: Close, dtype: int64

# %%
google["Close"].apply(rank_performance).value_counts().plot()

# %%
google["Close"].apply(rank_performance).value_counts().plot(kind="bar")

# %%
google["Close"].apply(rank_performance).value_counts().plot(kind="barh")

# %% [markdown]
# # Pie Charts

# %%
google["Close"].mean()
# Out:
# 737.1707774577945

# %%
def rank_performance1(stock_price):
    if stock_price <=737.1707774577945:
        return "Above Average"
    else:
        return "Below Average"

# %%
google["Close"].apply(rank_performance1).value_counts().plot()

# %%
google["Close"].apply(rank_performance1).value_counts().plot(kind="pie",legend=True)

# %% [markdown]
# # Histograms

# %%
def custom_round(stock_price):
    return int(stock_price/100.0) * 100

# %%
google["High"].apply(custom_round).value_counts()
# Out:
# 500     327
# 700     276
# 900     127
# 800      89
# 600      85
# 1000     60
# 1100     42
# 400       1
# Name: High, dtype: int64

# %%
google["High"].apply(custom_round).value_counts().sort_index()
# Out:
# 400       1
# 500     327
# 600      85
# 700     276
# 800      89
# 900     127
# 1000     60
# 1100     42
# Name: High, dtype: int64

# %%
google["High"].apply(custom_round).nunique()
# Out:
# 8

# %%
google["High"].apply(custom_round).plot(kind="hist",bins=9)
