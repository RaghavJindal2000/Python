# %%
import pandas as pd
from pandas_datareader import data

# %%
import pandas as pd
import quandl
import datetime
 
start = datetime.datetime(2000,1,1)
end = datetime.date.today()
 
s = "GOOG"
google = quandl.get("WIKI/" + s, start_date=start, end_date=end)
 
type(google)
# Out:
# pandas.core.frame.DataFrame

# %%
quandl.ApiConfig.api_key = "MNBZTzMd6Xyyimm6o91A"
cdata = quandl.get_table('WIKI/PRICES', qopts = { 'columns': ['ticker', 'date','open','high','low','close','Volume'] }, ticker = ["MSFT","GOOG","AAPL","YHOO","AMZN"], date = { 'gte': '2016-01-01', 'lte': '2016-12-31' })

# %% [markdown]
# # The Axes of a Panel Object

# %%
cdata
# Out:
#      ticker       date    open      high       low   close       volume
# None
# 0      YHOO 2016-12-30   38.72   39.0000   38.4300   38.67    6432792.0
# 1      YHOO 2016-12-29   38.76   38.9300   38.4800   38.64    4170497.0
# 2      YHOO 2016-12-28   39.12   39.2200   38.7100   38.73    4428368.0
# 3      YHOO 2016-12-27   38.59   39.0650   38.5000   38.92    4240285.0
# 4      YHOO 2016-12-23   38.46   38.8100   38.3700   38.66    3841245.0
# 5      YHOO 2016-12-22   38.69   38.7900   38.2600   38.50   11685650.0
# 6      YHOO 2016-12-21   39.08   39.3200   38.9700   39.15    8296515.0
# 7      YHOO 2016-12-20   38.40   39.1800   38.2400   39.16   25008427.0
# 8      YHOO 2016-12-19   38.66   38.7900   38.2700   38.42   13615511.0
# 9      YHOO 2016-12-16   38.62   39.2200   38.4200   38.61   21694081.0
# 10     YHOO 2016-12-15   40.00   40.0000   38.2500   38.41   43669990.0
# 11     YHOO 2016-12-14   41.44   41.5300   40.8300   40.91   19555694.0
# ...

# %%
# creating an empty panel
import pandas as pd
import numpy as np

data = np.random.rand(5,1709,5)
p = pd.Panel(data)
print (p)
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 5 (items) x 1709 (major_axis) x 5 (minor_axis)
# Items axis: 0 to 4
# Major_axis axis: 0 to 1708
# Minor_axis axis: 0 to 4

# %%
p1 = pd.Panel(cdata)
print (p1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-8490b53ae4aa> in <module>
# ----> 1 p1 = pd.Panel(cdata)
#       2 print (p1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\panel.py in __init__(self, data, items, major_axis, minor_axis, copy, dtype)
#     153
#     154         self._init_data(data=data, items=items, major_axis=major_axis,
# --> 155                         minor_axis=minor_axis, copy=copy, dtype=dtype)
#     156
#     157     def _init_data(self, data, copy, dtype, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\core\panel.py in _init_data(self, data, copy, dtype, **kwargs)
#     192             copy = False
#     193         else:  # pragma: no cover
# --> 194             raise ValueError('Panel constructor not properly called!')
#     195
#     196         NDFrame.__init__(self, mgr, axes=axes, copy=copy, dtype=dtype)
#
# ...

# %%
p.items  # WIll tell column names of data
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
p.major_axis  #acco to date time data will give datetime index
# Out:
# RangeIndex(start=0, stop=1709, step=1)

# %%
p.minor_axis  #acco to date time data will give company names used
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
p.axes  # Acc Would give all the above three colums together
# Out:
# [RangeIndex(start=0, stop=5, step=1),
#  RangeIndex(start=0, stop=1709, step=1),
#  RangeIndex(start=0, stop=5, step=1)]

# %% [markdown]
# # Panel Attributes

# %%
# creating an empty panel
import pandas as pd
import numpy as np

data = np.random.rand(5,1709,5)
p = pd.Panel(data)
print (p)
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 5 (items) x 1709 (major_axis) x 5 (minor_axis)
# Items axis: 0 to 4
# Major_axis axis: 0 to 1708
# Minor_axis axis: 0 to 4
# C:\Users\Raghav\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3296: FutureWarning:
# Panel is deprecated and will be removed in a future version.
# The recommended way to represent these types of 3-dimensional data are with a MultiIndex on a DataFrame, via the Panel.to_frame() method
# Alternatively, you can use the xarray package http://xarray.pydata.org/en/stable/.
# Pandas provides a `.to_xarray()` method to help automate this conversion.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
p.axes
# Out:
# [RangeIndex(start=0, stop=5, step=1),
#  RangeIndex(start=0, stop=1709, step=1),
#  RangeIndex(start=0, stop=5, step=1)]

# %%
p.items
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
p.major_axis
# Out:
# RangeIndex(start=0, stop=1709, step=1)

# %%
p.minor_axis
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
p.ndim
# Out:
# 3

# %%
p.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
p.shape
# Out:
# (5, 1709, 5)

# %%
p.size
# Out:
# 42725

# %%
5*1709*5
# Out:
# 42725

# %%
#to Reference three values needed

# %%
p.values
# Out:
# array([[[1.67556819e-01, 6.79685508e-01, 4.27179210e-02, 2.19430138e-01,
#          4.67089967e-02],
#         [1.91970223e-01, 8.58990797e-01, 3.18266180e-01, 4.60879382e-01,
#          7.13744502e-01],
#         [3.47570063e-03, 7.18133790e-01, 9.90026671e-01, 6.45096126e-01,
#          2.07843244e-01],
#         ...,
#         [1.59174951e-01, 2.17304811e-02, 1.30071247e-01, 3.42628306e-02,
#          5.18546443e-01],
#         [9.01459760e-01, 4.51842025e-01, 6.69419413e-01, 7.49783098e-01,
#          4.66572108e-02],
#         [8.45268397e-01, 2.00119216e-01, 6.83094791e-01, 1.47447209e-01,
#          1.30036772e-01]],
#
#        [[6.89959896e-01, 4.30851217e-01, 7.83705333e-01, 9.83460695e-01,
#          1.12762563e-01],
#         [4.44976933e-01, 2.36987499e-01, 7.51768590e-01, 8.55909949e-01,
#          7.60952364e-01],
#         [7.99785084e-02, 4.56188080e-02, 7.89552716e-01, 1.31129632e-01,
#          9.87177136e-01],
#         ...,
# ...

# %% [markdown]
# # Use Bracket Notation to Extract a DataFrame

# %%
import pandas as pd
import quandl
import datetime
 
start = datetime.datetime(2000,1,1)
end = datetime.date.today()
 
s = "GOOG"
google = quandl.get("WIKI/" + s, start_date=start, end_date=end)
p = pd.Panel(google)
print (p)
type(google)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-0d7be60a0f06> in <module>
#       8 s = "GOOG"
#       9 google = quandl.get("WIKI/" + s, start_date=start, end_date=end)
# ---> 10 p = pd.Panel(google)
#      11 print (p)
#      12 type(google)
#
# ~\Anaconda3\lib\site-packages\pandas\core\panel.py in __init__(self, data, items, major_axis, minor_axis, copy, dtype)
#     153
#     154         self._init_data(data=data, items=items, major_axis=major_axis,
# --> 155                         minor_axis=minor_axis, copy=copy, dtype=dtype)
#     156
#     157     def _init_data(self, data, copy, dtype, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\core\panel.py in _init_data(self, data, copy, dtype, **kwargs)
#     192             copy = False
#     193         else:  # pragma: no cover
# ...

# %%
# Deprecated since version 0.20.0: The recommended way to represent 3-D data are with a MultiIndex on a DataFrame via the to_frame() method or with the xarray package. Pandas provides a to_xarray() method to automate this conversion.
# Parameters:	
# data : ndarray (items x major x minor), or dict of DataFrames
# items : Index or array-like
# axis=0

# major_axis : Index or array-like
# axis=1

# minor_axis : Index or array-like
# axis=2

# copy : boolean, default False
# Copy data from inputs. Only affects DataFrame / 2d ndarray input

# dtype : dtype, default None
# Data type to force, otherwise infer

# %% [markdown]
# # Extraction Methods

# %%
#.loc,iloc,.ix methods learnt Before

# %% [markdown]
# # Convert Panel to MultiIndex

# %%
# with Help of .to_frame

# %%
p.to_frame()
# Out:
#                     0         1         2         3         4
# major minor
# 0     0      0.167557  0.689960  0.356853  0.180890  0.832109
#       1      0.679686  0.430851  0.762044  0.583587  0.533735
#       2      0.042718  0.783705  0.756388  0.140698  0.712294
#       3      0.219430  0.983461  0.273559  0.451196  0.852065
#       4      0.046709  0.112763  0.181220  0.734925  0.513689
# 1     0      0.191970  0.444977  0.899929  0.303398  0.345327
#       1      0.858991  0.236987  0.654808  0.833567  0.423730
#       2      0.318266  0.751769  0.402429  0.481002  0.988400
#       3      0.460879  0.855910  0.724382  0.337458  0.974164
#       4      0.713745  0.760952  0.770111  0.649222  0.953671
# 2     0      0.003476  0.079979  0.322621  0.749989  0.280838
#       1      0.718134  0.045619  0.816702  0.147835  0.674262
#       2      0.990027  0.789553  0.458574  0.483845  0.514419
#       3      0.645096  0.131130  0.213163  0.489722  0.642431
# ...

# %%
#to_panel() is used on the data finc for multiindex
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-3169cbfce0a4> in <module>
# ----> 1 data.to_panel()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'to_panel'

# %% [markdown]
# # .Major_xs

# %%
p.items
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
p[1]
# Out:
#              0         1         2         3         4
# 0     0.689960  0.430851  0.783705  0.983461  0.112763
# 1     0.444977  0.236987  0.751769  0.855910  0.760952
# 2     0.079979  0.045619  0.789553  0.131130  0.987177
# 3     0.271069  0.085692  0.000821  0.565264  0.315250
# 4     0.748822  0.963909  0.965308  0.732869  0.668835
# 5     0.395352  0.731845  0.938765  0.690932  0.166238
# 6     0.642178  0.994922  0.252852  0.371882  0.991748
# 7     0.727521  0.518961  0.053984  0.411456  0.937686
# 8     0.953279  0.352902  0.592100  0.401412  0.896099
# 9     0.702420  0.434752  0.226490  0.980059  0.667466
# 10    0.712650  0.951224  0.613856  0.622529  0.546246
# 11    0.571427  0.056699  0.813427  0.561166  0.234358
# 12    0.714646  0.350245  0.310020  0.454782  0.166903
# 13    0.002085  0.580280  0.150177  0.647326  0.228065
# 14    0.575422  0.228029  0.124543  0.505657  0.639599
# 15    0.655699  0.206657  0.514789  0.531306  0.143501
# ...

# %%
p.major_axis
# Out:
# RangeIndex(start=0, stop=1709, step=1)

# %%
p.major_xs(3)
# Out:
#           0         1         2         3         4
# 0  0.826585  0.271069  0.269734  0.834316  0.177352
# 1  0.213962  0.085692  0.576091  0.173020  0.835669
# 2  0.847319  0.000821  0.651795  0.646027  0.889322
# 3  0.487910  0.565264  0.823973  0.281214  0.113611
# 4  0.857886  0.315250  0.161536  0.329349  0.225306

# %% [markdown]
# # .Minor_xs

# %%
p.items
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
p.minor_axis
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
p.minor_xs(4)  #cut out one of the dimensions
# Out:
#              0         1         2         3         4
# 0     0.046709  0.112763  0.181220  0.734925  0.513689
# 1     0.713745  0.760952  0.770111  0.649222  0.953671
# 2     0.207843  0.987177  0.648927  0.912828  0.287350
# 3     0.857886  0.315250  0.161536  0.329349  0.225306
# 4     0.295420  0.668835  0.241297  0.248785  0.030748
# 5     0.321725  0.166238  0.393184  0.186191  0.672646
# 6     0.455179  0.991748  0.908424  0.187759  0.095314
# 7     0.823600  0.937686  0.403816  0.855029  0.029283
# 8     0.903018  0.896099  0.742500  0.660359  0.996062
# 9     0.657896  0.667466  0.242362  0.222935  0.896405
# 10    0.334680  0.546246  0.272301  0.507724  0.371744
# 11    0.426794  0.234358  0.693277  0.581002  0.798822
# 12    0.725914  0.166903  0.959915  0.455059  0.960502
# 13    0.590759  0.228065  0.821800  0.633833  0.221023
# 14    0.767689  0.639599  0.809207  0.886524  0.637475
# 15    0.809245  0.143501  0.070045  0.826401  0.456697
# ...

# %% [markdown]
# # Transpose with a .transpose() Method

# %%
p.axes
# Out:
# [RangeIndex(start=0, stop=5, step=1),
#  RangeIndex(start=0, stop=1709, step=1),
#  RangeIndex(start=0, stop=5, step=1)]

# %%
p.transpose(2,1,0)   # should have changed data acc to datase
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 5 (items) x 1709 (major_axis) x 5 (minor_axis)
# Items axis: 0 to 4
# Major_axis axis: 0 to 1708
# Minor_axis axis: 0 to 4

# %%
p
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 5 (items) x 1709 (major_axis) x 5 (minor_axis)
# Items axis: 0 to 4
# Major_axis axis: 0 to 1708
# Minor_axis axis: 0 to 4

# %% [markdown]
# #  Swapaxes()

# %%
p.swapaxes(2,1) # Swap axes basically likt transpose but easy
# Out:
# C:\Users\Raghav\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# Panel is deprecated and will be removed in a future version.
# The recommended way to represent these types of 3-dimensional data are with a MultiIndex on a DataFrame, via the Panel.to_frame() method
# Alternatively, you can use the xarray package http://xarray.pydata.org/en/stable/.
# Pandas provides a `.to_xarray()` method to help automate this conversion.
#
#   """Entry point for launching an IPython kernel.
# <class 'pandas.core.panel.Panel'>
# Dimensions: 5 (items) x 5 (major_axis) x 1709 (minor_axis)
# Items axis: 0 to 4
# Major_axis axis: 0 to 4
# Minor_axis axis: 0 to 1708
